# %%
/Volumes/pwahle/images/plate6/cycle1/zproject/MAX_Time00000_Point0000_Point0000_ChannelSCF_SD\ 1_PW.tif

# %%
#start all integration scripts like this

import sys
sys.path.append('/home/pwahle/Organoid-Image-Analysis/scripts/modules')
#alternative to sys.append('...'):
#set PYTHONPATH; in ~/.bashrc add below last line: export PYTHONPATH=/home/<your username>/Organoid-Image-Analysis/scripts/modules
#this option doesn't work for me.

import yaml 
import Paths #all kinds of paths, image paths are functions with default variables plate = "plate6", cycle = 'cycle1'; aligned_images_path has no variable 'cylce'. 


#load parameters
with open("../../params.yml", 'r') as ymlfile: 
    cfg = yaml.load(ymlfile, Loader=yaml.FullLoader)
    
globals().update(cfg) # optional, 'activates' all parameters

# %%
from skimage import io
from matplotlib import pyplot as plt
from skimage import filters
import os
import cv2 as cv
import numpy as np
import matplotlib
from skimage.filters import threshold_otsu
from skimage.filters import threshold_multiotsu
import copy
from skimage.feature import blob_log

folder = "/home/pwahle/images/plate6/cycle1/zproject/"

'''img = []

for i in os.listdir(folder):
    if i.endswith('.' + "tif"):
        img.append(io.imread(os.path.join(folder, i)))'''
        
test = io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0000_ChannelSCF_SD 1_PW.tif'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-7de575d5f1f5> in <module>()
#      17 for i in os.listdir(folder):
#      18     if i.endswith('.' + "tif"):
# ---> 19         img.append(io.imread(os.path.join(folder, i)))
#      20
#      21 test = io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0000_ChannelSCF_SD 1_PW.tif'))
#
# /home/pwahle/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      46
#      47     with file_or_url_context(fname) as fname:
# ---> 48         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      49
#      50     if not hasattr(img, 'ndim'):
#
# /home/pwahle/anaconda3/lib/python3.7/site-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     208                                (plugin, kind))
#     209
# ...

# %%
test = [] 


test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0000_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0001_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0002_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0003_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0004_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0005_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0006_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0007_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0008_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0009_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0010_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0011_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0012_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0013_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0014_ChannelSCF_SD 1_PW.tif')))
test.append(io.imread(os.path.join(folder, 'MAX_Time00000_Point0000_Point0015_ChannelSCF_SD 1_PW.tif')))

# %%
plt.hist(np.ravel(test[9]), 256)
plt.show()

# %%
thresholds = []

for i in test:
    thresholds.append(threshold_otsu(i))

# %%
plt.plot(thresholds)

# %%
plt.imshow(test[8])

# %%
tested = copy.deepcopy(test)
for i in tested:
    i < 200

# %%
plt.imshow(tested[9])

# %%
plt.imshow(tested[9]<200)
